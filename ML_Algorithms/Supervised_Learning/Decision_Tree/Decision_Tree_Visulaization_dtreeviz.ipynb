# %%
import graphviz.backend as be

# %%
from sklearn.datasets import *
from dtreeviz.trees import*
from IPython.display import Image,display_svg,SVG # jupyter notebook not for pycharam

# %%
classification = tree.DecisionTreeClassifier()

iris= load_iris()

X_train = iris.data
Y_train = iris.target

classification.fit(X_train,Y_train)
# Out:
# DecisionTreeClassifier()

# %%
classification.__dict__
# Out:
# {'criterion': 'gini',
#  'splitter': 'best',
#  'max_depth': None,
#  'min_samples_split': 2,
#  'min_samples_leaf': 1,
#  'min_weight_fraction_leaf': 0.0,
#  'max_features': None,
#  'max_leaf_nodes': None,
#  'random_state': None,
#  'min_impurity_decrease': 0.0,
#  'class_weight': None,
#  'ccp_alpha': 0.0,
#  'n_features_in_': 4,
#  'n_outputs_': 1,
#  'classes_': array([0, 1, 2]),
#  'n_classes_': 3,
#  'max_features_': 4,
#  'tree_': <sklearn.tree._tree.Tree at 0x7f91ac9ca870>}

# %%
from sklearn.tree import plot_tree
plot_tree(classification)
# Out:
# [Text(0.5, 0.9166666666666666, 'x[2] <= 2.45\ngini = 0.667\nsamples = 150\nvalue = [50, 50, 50]'),
#  Text(0.4230769230769231, 0.75, 'gini = 0.0\nsamples = 50\nvalue = [50, 0, 0]'),
#  Text(0.5769230769230769, 0.75, 'x[3] <= 1.75\ngini = 0.5\nsamples = 100\nvalue = [0, 50, 50]'),
#  Text(0.3076923076923077, 0.5833333333333334, 'x[2] <= 4.95\ngini = 0.168\nsamples = 54\nvalue = [0, 49, 5]'),
#  Text(0.15384615384615385, 0.4166666666666667, 'x[3] <= 1.65\ngini = 0.041\nsamples = 48\nvalue = [0, 47, 1]'),
#  Text(0.07692307692307693, 0.25, 'gini = 0.0\nsamples = 47\nvalue = [0, 47, 0]'),
#  Text(0.23076923076923078, 0.25, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
#  Text(0.46153846153846156, 0.4166666666666667, 'x[3] <= 1.55\ngini = 0.444\nsamples = 6\nvalue = [0, 2, 4]'),
#  Text(0.38461538461538464, 0.25, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3]'),
#  Text(0.5384615384615384, 0.25, 'x[0] <= 6.95\ngini = 0.444\nsamples = 3\nvalue = [0, 2, 1]'),
# ...

# %% [markdown]
# ## 1. Classification

# %%
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')
import dtreeviz
import matplotlib
viz = dtreeviz.model(classification, X_train, Y_train,
           target_name='play_tennis',
           feature_names = iris.feature_names,
           class_names=["setosa","versicolor","virginica"],)

# %%
viz.view(scale=1.5)
# Out:
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# ...

# %% [markdown]
# ## 2.Regression

# %%
regr = tree.DecisionTreeRegressor()
boston = pd.read_csv('Boston_Regression.csv')
boston
# Out:
#      Unnamed: 0  CRIM    ZN  INDUS  CHAS   NOX    RM    AGE   DIS  RAD    TAX
# 0             0  0.01  18.0   2.31   0.0  0.54  6.58  65.20  4.09  1.0  296.0  \
# 1             1  0.03   0.0   7.07   0.0  0.47  6.42  78.90  4.97  2.0  242.0
# 2             2  0.03   0.0   7.07   0.0  0.47  7.18  61.10  4.97  2.0  242.0
# 3             3  0.03   0.0   2.18   0.0  0.46  7.00  45.80  6.06  3.0  222.0
# 4             4  0.07   0.0   2.18   0.0  0.46  7.15  54.20  6.06  3.0  222.0
# ..          ...   ...   ...    ...   ...   ...   ...    ...   ...  ...    ...
# 501         501  0.06   0.0  11.93   0.0  0.57  6.59  69.10  2.48  1.0  273.0
# 502         502  0.05   0.0  11.93   0.0  0.57  6.12  76.70  2.29  1.0  273.0
# 503         503  0.06   0.0  11.93   0.0  0.57  6.98  91.00  2.17  1.0  273.0
# 504         504  0.11   0.0  11.93   0.0  0.57  6.79  89.30  2.39  1.0  273.0
# 505         505  0.05   0.0  11.93   0.0  0.57  6.03  68.52  2.50  1.0  273.0
#
# ...

# %%
boston.set_index('Unnamed: 0',inplace=True)

# %%
boston
# Out:
#             CRIM    ZN  INDUS  CHAS   NOX    RM    AGE   DIS  RAD    TAX
# Unnamed: 0
# 0           0.01  18.0   2.31   0.0  0.54  6.58  65.20  4.09  1.0  296.0  \
# 1           0.03   0.0   7.07   0.0  0.47  6.42  78.90  4.97  2.0  242.0
# 2           0.03   0.0   7.07   0.0  0.47  7.18  61.10  4.97  2.0  242.0
# 3           0.03   0.0   2.18   0.0  0.46  7.00  45.80  6.06  3.0  222.0
# 4           0.07   0.0   2.18   0.0  0.46  7.15  54.20  6.06  3.0  222.0
# ...          ...   ...    ...   ...   ...   ...    ...   ...  ...    ...
# 501         0.06   0.0  11.93   0.0  0.57  6.59  69.10  2.48  1.0  273.0
# 502         0.05   0.0  11.93   0.0  0.57  6.12  76.70  2.29  1.0  273.0
# 503         0.06   0.0  11.93   0.0  0.57  6.98  91.00  2.17  1.0  273.0
# 504         0.11   0.0  11.93   0.0  0.57  6.79  89.30  2.39  1.0  273.0
# 505         0.05   0.0  11.93   0.0  0.57  6.03  68.52  2.50  1.0  273.0
#
#             PTRATIO       B  LSTAT  MEDV
# Unnamed: 0
# ...

# %% [markdown]
# ### The Boston Housing Dataset
#
#     The Boston Housing Dataset is a derived from information collected by the U.S. Census Service concerning housing in the area of Boston MA. The following describes the dataset columns:
#
#     CRIM - per capita crime rate by town
#     ZN - proportion of residential land zoned for lots over 25,000 sq.ft.
#     INDUS - proportion of non-retail business acres per town.
#     CHAS - Charles River dummy variable (1 if tract bounds river; 0 otherwise)
#     NOX - nitric oxides concentration (parts per 10 million)
#     RM - average number of rooms per dwelling
#     AGE - proportion of owner-occupied units built prior to 1940
#     DIS - weighted distances to five Boston employment centres
#     RAD - index of accessibility to radial highways
#     TAX - full-value property-tax rate per $10,000
#     PTRATIO - pupil-teacher ratio by town
#     B - 1000(Bk - 0.63)^2 where Bk is the proportion of blacks by town
#     LSTAT - % lower status of the population
#     MEDV - Median value of owner-occupied homes in $1000's

# %%
boston.columns
# Out:
# Index(['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX',
#        'PTRATIO', 'B', 'LSTAT', 'MEDV'],
#       dtype='object')

# %%
regr = tree.DecisionTreeRegressor(max_depth=2)
X_train = boston.iloc[:,0:-1]
Y_train = boston.iloc[:,-1]
regr.fit(X_train,Y_train)

viz = dtreeviz.model(regr, X_train, Y_train,
           target_name='MEDV',
           feature_names = boston.columns)
viz.view(scale=2)
# Out:
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# ...

# %% [markdown]
# ## Horizontal Decision Tree

# %%
regr = tree.DecisionTreeRegressor(max_depth=2)
X_train = boston.iloc[:,0:-1]
Y_train = boston.iloc[:,-1]
regr.fit(X_train,Y_train)

viz = dtreeviz.model(regr, X_train, Y_train,
           target_name='MEDV',
           feature_names = boston.columns)
viz.view(scale=2,orientation='LR')
# Out:
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# ...

# %% [markdown]
# ## 4. Show Prediction Path

# %%
clas = tree.DecisionTreeClassifier()
iris = load_iris()

X_train = iris.data
Y_train = iris.target

clas.fit(X_train,Y_train)

X = iris.data[np.random.randint(0,len(iris.data)),:] # any random row from iris dataset

# %%
viz = dtreeviz.model(clas, X_train, Y_train,
           feature_names = iris.feature_names,
           class_names=["setosa","versicolor","virginica"],)

# %%
X_test =iris.data[np.random.randint(0,len(iris.data)),:] # any random row from iris dataset
viz.view(x=X_test,scale=1.15)
# Out:
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# ...

# %%
X_test
# Out:
# array([6.4, 3.2, 4.5, 1.5])

# %% [markdown]
# ## Show Node Number

# %%
viz = dtreeviz.model(clas, X_train, Y_train,
           feature_names = iris.feature_names,
           class_names=["setosa","versicolor","virginica"])

viz.view(histtype='barstacked',scale=1.5,show_node_labels=True)
# Out:
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# ...

# %% [markdown]
# ## Without Graphs

# %%
viz = dtreeviz.model(clas, X_train, Y_train,
           feature_names = iris.feature_names,
           class_names=["setosa","versicolor","virginica"])

viz.view(histtype='barstacked',scale=1.5,show_node_labels=True,fancy=False)
# Out:
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# ...

# %%
viz.view(x=X_test,scale=1.15,show_just_path=True)
# Out:
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# ...

# %%
viz.view(x=X_test,scale=1.15,show_just_path=True)
# Out:
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# ...

# %% [markdown]
# ## Path in Plain English

# %%
X_test =iris.data[np.random.randint(0,len(iris.data)),:] # any random row from iris dataset
print(viz.explain_prediction_path(x=X_test))
# Out:
# 4.85 <= petal length (cm)
# 1.75 <= petal width (cm)

# %% [markdown]
# ## Feature Importance

# %%
viz.instance_feature_importance(X_test)
# Out:
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# ...

# %% [markdown]
# ## Univariate Regression

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.tree import DecisionTreeRegressor
from dtreeviz.trees import*

df_cars = pd.read_csv("auto-mpg.csv")

# %%
df_cars.head()
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model year
# 0  18.0          8         307.0        130    3504          12.0          70  \
# 1  15.0          8         350.0        165    3693          11.5          70
# 2  18.0          8         318.0        150    3436          11.0          70
# 3  16.0          8         304.0        150    3433          12.0          70
# 4  17.0          8         302.0        140    3449          10.5          70
#
#    origin                   car name
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320
# 2       1         plymouth satellite
# 3       1              amc rebel sst
# 4       1                ford torino

# %%
new_df = pd.read_csv("auto-mpg.csv",usecols=['mpg','cylinders','displacement','weight'])
new_df.head()
# Out:
#     mpg  cylinders  displacement  weight
# 0  18.0          8         307.0    3504
# 1  15.0          8         350.0    3693
# 2  18.0          8         318.0    3436
# 3  16.0          8         304.0    3433
# 4  17.0          8         302.0    3449

# %%
new_df.columns = ['MPG', 'CYL', 'ENG','WGT']
new_df
# Out:
#       MPG  CYL    ENG   WGT
# 0    18.0    8  307.0  3504
# 1    15.0    8  350.0  3693
# 2    18.0    8  318.0  3436
# 3    16.0    8  304.0  3433
# 4    17.0    8  302.0  3449
# ..    ...  ...    ...   ...
# 393  27.0    4  140.0  2790
# 394  44.0    4   97.0  2130
# 395  32.0    4  135.0  2295
# 396  28.0    4  120.0  2625
# 397  31.0    4  119.0  2720
#
# [398 rows x 4 columns]

# %%
X,Y = new_df[['WGT']], new_df['MPG']

# %%
dt =DecisionTreeRegressor(max_depth=3, criterion="squared_error")
dt.fit(X,Y)

fig = plt.figure()
ax = fig.gca()
dtreeviz.rtreeviz_univar(dt,X,Y,'WGT','MPG', ax=ax)
plt.show()
# Out:
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# ...

# %%
new_df = pd.read_csv("auto-mpg.csv",usecols=['mpg','cylinders','displacement','weight','horsepower'])
new_df.columns = ['MPG', 'CYL','ENG','WGT','HP']
new_df.head()
# Out:
#     MPG  CYL    ENG  WGT    HP
# 0  18.0    8  307.0  130  3504
# 1  15.0    8  350.0  165  3693
# 2  18.0    8  318.0  150  3436
# 3  16.0    8  304.0  150  3433
# 4  17.0    8  302.0  140  3449

# %%
new_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   MPG     398 non-null    float64
#  1   CYL     398 non-null    int64
#  2   ENG     398 non-null    float64
#  3   WGT     398 non-null    object
#  4   HP      398 non-null    int64
# dtypes: float64(2), int64(2), object(1)
# memory usage: 15.7+ KB

# %%
new_df['bool_Weight'] = new_df['WGT'].apply(lambda x: x.isdigit())
indexes = new_df[new_df['bool_Weight']==False].index
new_df.drop(index=indexes,inplace=True)
new_df.drop(columns=['bool_Weight'],inplace=True)
new_df
# Out:
#       MPG  CYL    ENG  WGT    HP
# 0    18.0    8  307.0  130  3504
# 1    15.0    8  350.0  165  3693
# 2    18.0    8  318.0  150  3436
# 3    16.0    8  304.0  150  3433
# 4    17.0    8  302.0  140  3449
# ..    ...  ...    ...  ...   ...
# 393  27.0    4  140.0   86  2790
# 394  44.0    4   97.0   52  2130
# 395  32.0    4  135.0   84  2295
# 396  28.0    4  120.0   79  2625
# 397  31.0    4  119.0   82  2720
#
# [392 rows x 5 columns]

# %%
new_df = new_df.astype(str)
new_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 392 entries, 0 to 397
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   MPG     392 non-null    object
#  1   CYL     392 non-null    object
#  2   ENG     392 non-null    object
#  3   WGT     392 non-null    object
#  4   HP      392 non-null    object
# dtypes: object(5)
# memory usage: 18.4+ KB

# %%
from mpl_toolkits.mplot3d import Axes3D
from sklearn.tree import DecisionTreeRegressor
from dtreeviz.trees import *

X = new_df[['WGT','ENG']]
Y = new_df['MPG']

dt = DecisionTreeRegressor(max_depth=3,criterion="squared_error")
dt.fit(X,Y)

figsize = (6,5)
fig = plt.figure(figsize=figsize)
ax = fig.add_subplot(111,projection='3d')

dtreeviz.rtreeviz_bivar_3D(
           dt, X, Y,
           feature_names = ['WGT','HP'],
           target_name='MPG',
           fontsize=14,
           fontname='Arial',
           elev=20,
           azim=25,
           dist=8.2,
           show = {'splits','title'},
           ax = ax
)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[193], line 15
#      12 fig = plt.figure(figsize=figsize)
#      13 ax = fig.add_subplot(111,projection='3d')
# ---> 15 dtreeviz.rtreeviz_bivar_3D(
#      16            dt, X, Y,
#      17            feature_names = ['WGT','HP'],
#      18            target_name='MPG',
#      19            fontsize=14,
#      20            fontname='Arial',
#      21            elev=20,
#      22            azim=25,
#      23            dist=8.2,
#      24            show = {'splits','title'},
#      25            ax = ax
#      26 )
#      27 plt.show()
#
# File ~/.local/lib/python3.10/site-packages/dtreeviz/compatibility.py:103, in rtreeviz_bivar_3D(tree_model, X_train, y_train, feature_names, target_name, class_names, tree_index, ax, fontsize, ticks_fontsize, fontname, azim, elev, dist, show, colors, markersize, n_colors_in_map)
# ...
