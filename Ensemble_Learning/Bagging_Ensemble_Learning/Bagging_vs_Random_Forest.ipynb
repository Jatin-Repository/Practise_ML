# %%
import numpy as np
import pandas as pd
from sklearn.datasets import make_classification
from sklearn.ensemble import BaggingClassifier,RandomForestClassifier
from sklearn.tree import plot_tree
import matplotlib.pyplot as plt

# %%
X,Y = make_classification(n_features=5, n_redundant=0, n_informative=5,n_clusters_per_class=1)

# %%
df = pd.DataFrame(X,columns=['cols1','cols2','cols3','col4','col5'])

df['target'] = Y
df.head()
# Out:
#       cols1     cols2     cols3      col4      col5  target
# 0 -1.398663 -0.685082 -2.015932 -1.305295  0.173775       0
# 1 -3.193763 -0.245887 -2.966537  0.977555  1.510454       0
# 2 -2.208804  1.713993 -0.048973 -1.015732  0.818667       1
# 3 -1.066283  1.642877  0.065354 -0.340437  0.580930       1
# 4 -0.665581 -0.167908  0.156931  1.925613 -1.631796       1

# %%
bag = BaggingClassifier(max_features=2) # deafault Decision Tree

# %%
bag.fit(df.iloc[:,:5],df.iloc[:,-1])
# Out:
# BaggingClassifier(max_features=2)

# %%
bag.__dict__
# Out:
# {'estimator': None,
#  'n_estimators': 10,
#  'estimator_params': (),
#  'base_estimator': 'deprecated',
#  'max_samples': 1.0,
#  'max_features': 2,
#  'bootstrap': True,
#  'bootstrap_features': False,
#  'oob_score': False,
#  'warm_start': False,
#  'n_jobs': None,
#  'random_state': None,
#  'verbose': 0,
#  'feature_names_in_': array(['cols1', 'cols2', 'cols3', 'col4', 'col5'], dtype=object),
#  'n_features_in_': 5,
#  '_n_samples': 100,
#  'classes_': array([0, 1]),
#  'n_classes_': 2,
#  'estimator_': DecisionTreeClassifier(),
#  '_max_samples': 100,
#  '_max_features': 2,
#  'estimators_': [DecisionTreeClassifier(random_state=1838338589),
#   DecisionTreeClassifier(random_state=690893368),
#   DecisionTreeClassifier(random_state=1608569770),
#   DecisionTreeClassifier(random_state=554260188),
#   DecisionTreeClassifier(random_state=744243788),
#   DecisionTreeClassifier(random_state=592972252),
#   DecisionTreeClassifier(random_state=879224958),
#   DecisionTreeClassifier(random_state=1281725152),
#   DecisionTreeClassifier(random_state=1991124891),
#   DecisionTreeClassifier(random_state=1718967966)],
#  'estimators_features_': [array([3, 0]),
#   array([4, 1]),
#   array([4, 1]),
#   array([2, 1]),
#   array([2, 0]),
#   array([3, 2]),
#   array([1, 2]),
#   array([3, 2]),
#   array([0, 4]),
#   array([3, 1])],
#  '_seeds': array([1766325848, 1836337481, 2083811401, 1766229797,  337633619,
#         1867355853,  926902241,  470172008,   38690039,  331193623])}

# %%
plt.figure(figsize=(12,12))
plot_tree(bag.estimators_[0])
plt.show()

# %%
rf = RandomForestClassifier(max_features=2)

# %%
rf.fit(df.iloc[:,:5],df.iloc[:,-1])
# Out:
# RandomForestClassifier(max_features=2)

# %%
rf.__dict__
# Out:
# {'estimator': DecisionTreeClassifier(),
#  'n_estimators': 100,
#  'estimator_params': ('criterion',
#   'max_depth',
#   'min_samples_split',
#   'min_samples_leaf',
#   'min_weight_fraction_leaf',
#   'max_features',
#   'max_leaf_nodes',
#   'min_impurity_decrease',
#   'random_state',
#   'ccp_alpha'),
#  'base_estimator': 'deprecated',
#  'bootstrap': True,
#  'oob_score': False,
#  'n_jobs': None,
#  'random_state': None,
#  'verbose': 0,
#  'warm_start': False,
#  'class_weight': None,
#  'max_samples': None,
#  'criterion': 'gini',
#  'max_depth': None,
#  'min_samples_split': 2,
#  'min_samples_leaf': 1,
#  'min_weight_fraction_leaf': 0.0,
#  'max_features': 2,
#  'max_leaf_nodes': None,
#  'min_impurity_decrease': 0.0,
#  'ccp_alpha': 0.0,
#  'feature_names_in_': array(['cols1', 'cols2', 'cols3', 'col4', 'col5'], dtype=object),
#  'n_features_in_': 5,
#  'n_outputs_': 1,
#  'classes_': array([0, 1]),
#  'n_classes_': 2,
#  'estimator_': DecisionTreeClassifier(),
#  'estimators_': [DecisionTreeClassifier(max_features=2, random_state=1454245204),
#   DecisionTreeClassifier(max_features=2, random_state=2090912663),
#   DecisionTreeClassifier(max_features=2, random_state=590483304),
#   DecisionTreeClassifier(max_features=2, random_state=1922832403),
#   DecisionTreeClassifier(max_features=2, random_state=41549837),
#   DecisionTreeClassifier(max_features=2, random_state=2130548573),
#   DecisionTreeClassifier(max_features=2, random_state=719150976),
#   DecisionTreeClassifier(max_features=2, random_state=1301612469),
#   DecisionTreeClassifier(max_features=2, random_state=1490039725),
#   DecisionTreeClassifier(max_features=2, random_state=954022372),
#   DecisionTreeClassifier(max_features=2, random_state=438798217),
#   DecisionTreeClassifier(max_features=2, random_state=1376141295),
#   DecisionTreeClassifier(max_features=2, random_state=1433721972),
#   DecisionTreeClassifier(max_features=2, random_state=1610398147),
#   DecisionTreeClassifier(max_features=2, random_state=189814435),
#   DecisionTreeClassifier(max_features=2, random_state=123589557),
#   DecisionTreeClassifier(max_features=2, random_state=499369835),
#   DecisionTreeClassifier(max_features=2, random_state=564231437),
#   DecisionTreeClassifier(max_features=2, random_state=1160946684),
#   DecisionTreeClassifier(max_features=2, random_state=514917282),
#   DecisionTreeClassifier(max_features=2, random_state=568039194),
#   DecisionTreeClassifier(max_features=2, random_state=2011012625),
#   DecisionTreeClassifier(max_features=2, random_state=1403336837),
#   DecisionTreeClassifier(max_features=2, random_state=1210037638),
#   DecisionTreeClassifier(max_features=2, random_state=1411308258),
#   DecisionTreeClassifier(max_features=2, random_state=244446120),
#   DecisionTreeClassifier(max_features=2, random_state=252919584),
#   DecisionTreeClassifier(max_features=2, random_state=1737286296),
#   DecisionTreeClassifier(max_features=2, random_state=1079532407),
#   DecisionTreeClassifier(max_features=2, random_state=861818997),
#   DecisionTreeClassifier(max_features=2, random_state=1095535643),
#   DecisionTreeClassifier(max_features=2, random_state=822758259),
#   DecisionTreeClassifier(max_features=2, random_state=1330665051),
#   DecisionTreeClassifier(max_features=2, random_state=709411814),
#   DecisionTreeClassifier(max_features=2, random_state=1298917504),
#   DecisionTreeClassifier(max_features=2, random_state=1411483443),
#   DecisionTreeClassifier(max_features=2, random_state=837230621),
#   DecisionTreeClassifier(max_features=2, random_state=1946983929),
#   DecisionTreeClassifier(max_features=2, random_state=970650613),
#   DecisionTreeClassifier(max_features=2, random_state=374015356),
#   DecisionTreeClassifier(max_features=2, random_state=118263644),
#   DecisionTreeClassifier(max_features=2, random_state=330666580),
#   DecisionTreeClassifier(max_features=2, random_state=580228906),
#   DecisionTreeClassifier(max_features=2, random_state=244352561),
#   DecisionTreeClassifier(max_features=2, random_state=124350641),
#   DecisionTreeClassifier(max_features=2, random_state=1704740345),
#   DecisionTreeClassifier(max_features=2, random_state=555440060),
#   DecisionTreeClassifier(max_features=2, random_state=1109037420),
#   DecisionTreeClassifier(max_features=2, random_state=929904213),
#   DecisionTreeClassifier(max_features=2, random_state=1658295826),
#   DecisionTreeClassifier(max_features=2, random_state=92729914),
#   DecisionTreeClassifier(max_features=2, random_state=140435472),
#   DecisionTreeClassifier(max_features=2, random_state=1468366223),
#   DecisionTreeClassifier(max_features=2, random_state=667453523),
#   DecisionTreeClassifier(max_features=2, random_state=1242542335),
#   DecisionTreeClassifier(max_features=2, random_state=1354374392),
#   DecisionTreeClassifier(max_features=2, random_state=401216750),
#   DecisionTreeClassifier(max_features=2, random_state=605527132),
#   DecisionTreeClassifier(max_features=2, random_state=440669805),
#   DecisionTreeClassifier(max_features=2, random_state=519784946),
#   DecisionTreeClassifier(max_features=2, random_state=964261858),
#   DecisionTreeClassifier(max_features=2, random_state=1296612416),
#   DecisionTreeClassifier(max_features=2, random_state=1618498336),
#   DecisionTreeClassifier(max_features=2, random_state=1927165815),
#   DecisionTreeClassifier(max_features=2, random_state=1019887075),
#   DecisionTreeClassifier(max_features=2, random_state=283953365),
#   DecisionTreeClassifier(max_features=2, random_state=1824729783),
#   DecisionTreeClassifier(max_features=2, random_state=202801923),
#   DecisionTreeClassifier(max_features=2, random_state=2112525211),
#   DecisionTreeClassifier(max_features=2, random_state=1154280092),
#   DecisionTreeClassifier(max_features=2, random_state=1125422996),
#   DecisionTreeClassifier(max_features=2, random_state=663708611),
#   DecisionTreeClassifier(max_features=2, random_state=1034406692),
#   DecisionTreeClassifier(max_features=2, random_state=1719837723),
#   DecisionTreeClassifier(max_features=2, random_state=185123817),
#   DecisionTreeClassifier(max_features=2, random_state=1054485878),
#   DecisionTreeClassifier(max_features=2, random_state=1291305440),
#   DecisionTreeClassifier(max_features=2, random_state=1312959232),
#   DecisionTreeClassifier(max_features=2, random_state=160307270),
#   DecisionTreeClassifier(max_features=2, random_state=841693583),
#   DecisionTreeClassifier(max_features=2, random_state=652344414),
#   DecisionTreeClassifier(max_features=2, random_state=1254716203),
#   DecisionTreeClassifier(max_features=2, random_state=1033106026),
#   DecisionTreeClassifier(max_features=2, random_state=1764300494),
#   DecisionTreeClassifier(max_features=2, random_state=1702252184),
#   DecisionTreeClassifier(max_features=2, random_state=774270586),
#   DecisionTreeClassifier(max_features=2, random_state=375117938),
#   DecisionTreeClassifier(max_features=2, random_state=1663316327),
#   DecisionTreeClassifier(max_features=2, random_state=247354157),
#   DecisionTreeClassifier(max_features=2, random_state=800040686),
#   DecisionTreeClassifier(max_features=2, random_state=1787896379),
#   DecisionTreeClassifier(max_features=2, random_state=23553827),
#   DecisionTreeClassifier(max_features=2, random_state=152872696),
#   DecisionTreeClassifier(max_features=2, random_state=1484587317),
#   DecisionTreeClassifier(max_features=2, random_state=404855363),
#   DecisionTreeClassifier(max_features=2, random_state=692125122),
#   DecisionTreeClassifier(max_features=2, random_state=800361637),
#   DecisionTreeClassifier(max_features=2, random_state=1463825437),
#   DecisionTreeClassifier(max_features=2, random_state=1792168957),
#   DecisionTreeClassifier(max_features=2, random_state=1819193434)]}

# %%
plt.figure(figsize=(12,12))
plot_tree(rf.estimators_[0])
plt.show()

# %%
rf.__dict__
# Out:
# {'estimator': DecisionTreeClassifier(),
#  'n_estimators': 100,
#  'estimator_params': ('criterion',
#   'max_depth',
#   'min_samples_split',
#   'min_samples_leaf',
#   'min_weight_fraction_leaf',
#   'max_features',
#   'max_leaf_nodes',
#   'min_impurity_decrease',
#   'random_state',
#   'ccp_alpha'),
#  'base_estimator': 'deprecated',
#  'bootstrap': True,
#  'oob_score': False,
#  'n_jobs': None,
#  'random_state': None,
#  'verbose': 0,
#  'warm_start': False,
#  'class_weight': None,
#  'max_samples': None,
#  'criterion': 'gini',
#  'max_depth': None,
#  'min_samples_split': 2,
#  'min_samples_leaf': 1,
#  'min_weight_fraction_leaf': 0.0,
#  'max_features': 2,
#  'max_leaf_nodes': None,
#  'min_impurity_decrease': 0.0,
#  'ccp_alpha': 0.0,
#  'feature_names_in_': array(['cols1', 'cols2', 'cols3', 'col4', 'col5'], dtype=object),
#  'n_features_in_': 5,
#  'n_outputs_': 1,
#  'classes_': array([0, 1]),
#  'n_classes_': 2,
#  'estimator_': DecisionTreeClassifier(),
#  'estimators_': [DecisionTreeClassifier(max_features=2, random_state=1454245204),
#   DecisionTreeClassifier(max_features=2, random_state=2090912663),
#   DecisionTreeClassifier(max_features=2, random_state=590483304),
#   DecisionTreeClassifier(max_features=2, random_state=1922832403),
#   DecisionTreeClassifier(max_features=2, random_state=41549837),
#   DecisionTreeClassifier(max_features=2, random_state=2130548573),
#   DecisionTreeClassifier(max_features=2, random_state=719150976),
#   DecisionTreeClassifier(max_features=2, random_state=1301612469),
#   DecisionTreeClassifier(max_features=2, random_state=1490039725),
#   DecisionTreeClassifier(max_features=2, random_state=954022372),
#   DecisionTreeClassifier(max_features=2, random_state=438798217),
#   DecisionTreeClassifier(max_features=2, random_state=1376141295),
#   DecisionTreeClassifier(max_features=2, random_state=1433721972),
#   DecisionTreeClassifier(max_features=2, random_state=1610398147),
#   DecisionTreeClassifier(max_features=2, random_state=189814435),
#   DecisionTreeClassifier(max_features=2, random_state=123589557),
#   DecisionTreeClassifier(max_features=2, random_state=499369835),
#   DecisionTreeClassifier(max_features=2, random_state=564231437),
#   DecisionTreeClassifier(max_features=2, random_state=1160946684),
#   DecisionTreeClassifier(max_features=2, random_state=514917282),
#   DecisionTreeClassifier(max_features=2, random_state=568039194),
#   DecisionTreeClassifier(max_features=2, random_state=2011012625),
#   DecisionTreeClassifier(max_features=2, random_state=1403336837),
#   DecisionTreeClassifier(max_features=2, random_state=1210037638),
#   DecisionTreeClassifier(max_features=2, random_state=1411308258),
#   DecisionTreeClassifier(max_features=2, random_state=244446120),
#   DecisionTreeClassifier(max_features=2, random_state=252919584),
#   DecisionTreeClassifier(max_features=2, random_state=1737286296),
#   DecisionTreeClassifier(max_features=2, random_state=1079532407),
#   DecisionTreeClassifier(max_features=2, random_state=861818997),
#   DecisionTreeClassifier(max_features=2, random_state=1095535643),
#   DecisionTreeClassifier(max_features=2, random_state=822758259),
#   DecisionTreeClassifier(max_features=2, random_state=1330665051),
#   DecisionTreeClassifier(max_features=2, random_state=709411814),
#   DecisionTreeClassifier(max_features=2, random_state=1298917504),
#   DecisionTreeClassifier(max_features=2, random_state=1411483443),
#   DecisionTreeClassifier(max_features=2, random_state=837230621),
#   DecisionTreeClassifier(max_features=2, random_state=1946983929),
#   DecisionTreeClassifier(max_features=2, random_state=970650613),
#   DecisionTreeClassifier(max_features=2, random_state=374015356),
#   DecisionTreeClassifier(max_features=2, random_state=118263644),
#   DecisionTreeClassifier(max_features=2, random_state=330666580),
#   DecisionTreeClassifier(max_features=2, random_state=580228906),
#   DecisionTreeClassifier(max_features=2, random_state=244352561),
#   DecisionTreeClassifier(max_features=2, random_state=124350641),
#   DecisionTreeClassifier(max_features=2, random_state=1704740345),
#   DecisionTreeClassifier(max_features=2, random_state=555440060),
#   DecisionTreeClassifier(max_features=2, random_state=1109037420),
#   DecisionTreeClassifier(max_features=2, random_state=929904213),
#   DecisionTreeClassifier(max_features=2, random_state=1658295826),
#   DecisionTreeClassifier(max_features=2, random_state=92729914),
#   DecisionTreeClassifier(max_features=2, random_state=140435472),
#   DecisionTreeClassifier(max_features=2, random_state=1468366223),
#   DecisionTreeClassifier(max_features=2, random_state=667453523),
#   DecisionTreeClassifier(max_features=2, random_state=1242542335),
#   DecisionTreeClassifier(max_features=2, random_state=1354374392),
#   DecisionTreeClassifier(max_features=2, random_state=401216750),
#   DecisionTreeClassifier(max_features=2, random_state=605527132),
#   DecisionTreeClassifier(max_features=2, random_state=440669805),
#   DecisionTreeClassifier(max_features=2, random_state=519784946),
#   DecisionTreeClassifier(max_features=2, random_state=964261858),
#   DecisionTreeClassifier(max_features=2, random_state=1296612416),
#   DecisionTreeClassifier(max_features=2, random_state=1618498336),
#   DecisionTreeClassifier(max_features=2, random_state=1927165815),
#   DecisionTreeClassifier(max_features=2, random_state=1019887075),
#   DecisionTreeClassifier(max_features=2, random_state=283953365),
#   DecisionTreeClassifier(max_features=2, random_state=1824729783),
#   DecisionTreeClassifier(max_features=2, random_state=202801923),
#   DecisionTreeClassifier(max_features=2, random_state=2112525211),
#   DecisionTreeClassifier(max_features=2, random_state=1154280092),
#   DecisionTreeClassifier(max_features=2, random_state=1125422996),
#   DecisionTreeClassifier(max_features=2, random_state=663708611),
#   DecisionTreeClassifier(max_features=2, random_state=1034406692),
#   DecisionTreeClassifier(max_features=2, random_state=1719837723),
#   DecisionTreeClassifier(max_features=2, random_state=185123817),
#   DecisionTreeClassifier(max_features=2, random_state=1054485878),
#   DecisionTreeClassifier(max_features=2, random_state=1291305440),
#   DecisionTreeClassifier(max_features=2, random_state=1312959232),
#   DecisionTreeClassifier(max_features=2, random_state=160307270),
#   DecisionTreeClassifier(max_features=2, random_state=841693583),
#   DecisionTreeClassifier(max_features=2, random_state=652344414),
#   DecisionTreeClassifier(max_features=2, random_state=1254716203),
#   DecisionTreeClassifier(max_features=2, random_state=1033106026),
#   DecisionTreeClassifier(max_features=2, random_state=1764300494),
#   DecisionTreeClassifier(max_features=2, random_state=1702252184),
#   DecisionTreeClassifier(max_features=2, random_state=774270586),
#   DecisionTreeClassifier(max_features=2, random_state=375117938),
#   DecisionTreeClassifier(max_features=2, random_state=1663316327),
#   DecisionTreeClassifier(max_features=2, random_state=247354157),
#   DecisionTreeClassifier(max_features=2, random_state=800040686),
#   DecisionTreeClassifier(max_features=2, random_state=1787896379),
#   DecisionTreeClassifier(max_features=2, random_state=23553827),
#   DecisionTreeClassifier(max_features=2, random_state=152872696),
#   DecisionTreeClassifier(max_features=2, random_state=1484587317),
#   DecisionTreeClassifier(max_features=2, random_state=404855363),
#   DecisionTreeClassifier(max_features=2, random_state=692125122),
#   DecisionTreeClassifier(max_features=2, random_state=800361637),
#   DecisionTreeClassifier(max_features=2, random_state=1463825437),
#   DecisionTreeClassifier(max_features=2, random_state=1792168957),
#   DecisionTreeClassifier(max_features=2, random_state=1819193434)]}
